# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rc
from matplotlib import pyplot

# os x(mac os) 한글 font 


# 노트북 안에 그래플 그리기 위해 셋팅
# %matplotlib inline

# 그래프를 격자 스타일로 (숫자 범위가 눈에 잘 띄도록 ggplot 스타일 사용.)
plt.style.use("ggplot")

# 그래프에서 마이너스 폰트 깨지는 문제 해결을 위해
mpl.rcParams["axes.unicode_minus"] = False

# 경고 문구 무시
import warnings
warnings.filterwarnings(action='ignore')

from matplotlib import font_manager, rc
import platform

if platform.system() == 'Windows':
# 윈도우인 경우
    font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)
else:    
# Mac 인 경우
    rc('font', family='AppleGothic')
    
mpl.rcParams['axes.unicode_minus'] = False

# %%
df_apartment = pd.read_csv('./전국아파트.csv')
apartment_list = list(df_apartment.loc[:, '검색지역'])
apartment_list[0]
# Out:
# '경기도 수원시 영통구'

# %%
region_list = ['서울시', '부산광역시', '대구광역시', '인천광역시', '광주광역시', '대전광역시', '울산광역시', '세종시', '경기도', '강원도', '충청북도', '충청남도','전라북도', '전라남도', '경상북도', '경상남도', '제주도']
number_of_apartment = []

for i in region_list:
    count = 0
    for j in apartment_list:
        if i in j:
            count += 1
    number_of_apartment.append(count)
print(number_of_apartment)
# Out:
# [9109, 4672, 1896, 2401, 1069, 918, 1287, 202, 7512, 987, 1025, 1080, 1087, 780, 1413, 2328, 1046]

# %%
s = {}

for i in range(len(region_list)):
    s[region_list[i]] = number_of_apartment[i]

print(s)
# Out:
# {'서울시': 9109, '부산광역시': 4672, '대구광역시': 1896, '인천광역시': 2401, '광주광역시': 1069, '대전광역시': 918, '울산광역시': 1287, '세종시': 202, '경기도': 7512, '강원도': 987, '충청북도': 1025, '충청남도': 1080, '전라북도': 1087, '전라남도': 780, '경상북도': 1413, '경상남도': 2328, '제주도': 1046}

# %%
a = sorted(s.items(), key=lambda x:x[1])
print(a)
# Out:
# [('세종시', 202), ('전라남도', 780), ('대전광역시', 918), ('강원도', 987), ('충청북도', 1025), ('제주도', 1046), ('광주광역시', 1069), ('충청남도', 1080), ('전라북도', 1087), ('울산광역시', 1287), ('경상북도', 1413), ('대구광역시', 1896), ('경상남도', 2328), ('인천광역시', 2401), ('부산광역시', 4672), ('경기도', 7512), ('서울시', 9109)]

# %%
region_list = []
number_of_apartment = []

for i in range(len(a)):
    region_list.append(a[i][0])
    number_of_apartment.append(a[i][1])
print(region_list, number_of_apartment)
# Out:
# ['세종시', '전라남도', '대전광역시', '강원도', '충청북도', '제주도', '광주광역시', '충청남도', '전라북도', '울산광역시', '경상북도', '대구광역시', '경상남도', '인천광역시', '부산광역시', '경기도', '서울시'] [202, 780, 918, 987, 1025, 1046, 1069, 1080, 1087, 1287, 1413, 1896, 2328, 2401, 4672, 7512, 9109]

# %%
plt.figure(figsize=(18,10))
x = np.arange(len(region_list))
years = region_list
values = number_of_apartment

colors = ['beige', 'beige', 'beige',  'oldlace', 'oldlace', 'oldlace', 'oldlace', 'wheat', 'wheat', 'wheat', 'wheat','palegoldenrod', 'khaki', 'goldenrod', 'darkorange', 'orange', 'gold']
plt.barh(years, values, color=colors)
# plt.xticks(x, years)
plt.title("시도별 아파트 매물수(단지별)")
for i, v in enumerate(years):
    str_val = "%d" % values[i]
    pyplot.text(values[i], v, str_val, fontsize=15, color='#ff6600', horizontalalignment='left', verticalalignment = 'center')
plt.show()

# %%
ratio = [68.8, 11.7, 8.6, 7.8]
labels = ['자녀', '배우자', '본인', '기타']
colors = ['orange', 'darkorange', 'goldenrod', 'khaki']

plt.pie(ratio, labels=labels, autopct='%.1f%%', colors=colors)
plt.title("장기요양급여 이용에 대한 결정")
plt.show()

# %%
ratio = [34.0, 24.8, 31.9, 7.4]
labels = ['단독가구', '부부가구', '자녀동거가구', '손자녀 동거가구']
colors = ['orangered', 'tomato', 'lightsalmon', 'peachpuff']

plt.pie(ratio, labels=labels, autopct='%.1f%%', colors=colors)
plt.title("장기요양 가구특성")
plt.show()

# %%
ratio = [26.5, 25.6, 14.8, 26.5, 6.6]
labels = ['동일 읍면동', '동일 시군구', '동일 시, 도', '다른 시, 도', '기타']
colors = ['olive', 'yellowgreen', 'greenyellow', 'lime', 'forestgreen']

plt.pie(ratio, labels=labels, autopct='%.1f%%', colors=colors)
plt.title("노인 단독가구의 비동거 가족과의 거주 거리")
plt.show()

# %%
df_income = pd.read_csv('./1인당_개인소득_시도.csv')
df_income.head()
# Out:
#      시도별  2019 p)
# 0  서울특별시    23440
# 1  부산광역시    19680
# 2  대구광역시    19210
# 3  인천광역시    19332
# 4  광주광역시    20532

# %%
region_list = list(df_income.loc[:, '시도별'])
income = list(df_income.loc[:, '2019 p)'])
print(region_list, income)
# Out:
# ['서울특별시', '부산광역시', '대구광역시', '인천광역시', '광주광역시', '대전광역시', '울산광역시', '세종특별자치시', '경기도', '강원도', '충청북도', '충청남도', '전라북도', '전라남도', '경상북도', '경상남도', '제주특별자치도'] [23440, 19680, 19210, 19332, 20532, 20498, 22550, 19789, 20482, 18997, 18823, 18955, 18725, 18711, 18611, 18939, 18734]

# %%
plt.figure(figsize=(18, 8))
x = np.arange(len(income))
years = region_list
values = income
colors = ['darkkhaki']

plt.bar(x, values, color=colors)
plt.xticks(x, years)
plt.title("시도별 개인소득(천원)")
plt.show()
